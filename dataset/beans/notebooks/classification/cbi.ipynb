# %% [markdown]
# # Upload the BEANS cbi recordings to HF

# %% [markdown]
# #### 1. Download the recordings the way BEANS do it on their [GitHub](https://github.com/earthspecies/beans)

# %% [markdown]
# First we will navigate into the mounted data_birdset folder to download the temporary files from the Repo their and install wget & unzip as they are not on the university bash.

# %%
# %cd '../../../../data_birdset/beans'
# !pwd
# !sudo apt install wget
# !sudo apt install unzip
# Out:
# /workspace/data_birdset/beans
# /workspace/data_birdset/beans
# /workspace/.venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# wget is already the newest version (1.21.2-2ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unzip is already the newest version (6.0-26ubuntu3.2).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %% [markdown]
# Then we will run their script to download the metadata and recordings to have the same splits.

# %%
# Their script:
import sys
import pandas as pd
from plumbum import local, FG
from pathlib import Path
import random

sox = local['sox']
local['mkdir']['-p', 'data/cbi/wav']()
local['kaggle']['competitions', 'download', '-p', 'data/cbi', 'birdsong-recognition'] & FG
local['unzip']['data/cbi/birdsong-recognition.zip', '-d', 'data/cbi/'] & FG

random.seed(42)
df = pd.read_csv('data/cbi/train.csv')
all_recordist = df.recordist.unique()

random.shuffle(all_recordist)
train_recordist = set(all_recordist[:int(.6 * len(all_recordist))])
valid_recordist = set(all_recordist[int(.6 * len(all_recordist)):int(.8 * len(all_recordist))])
test_recordist = set(all_recordist[int(.8 * len(all_recordist)):])

def convert(row):
    if row['recordist'] in train_recordist:
        split = 'train'
    elif row['recordist'] in valid_recordist:
        split = 'valid'
    else:
        split = 'test'

    src_file = Path('data/cbi/train_audio') / row['ebird_code'] / row['filename']
    tgt_file = Path('data/cbi/wav') / (Path(row['filename']).stem + '.wav')
    print(f'Converting {src_file} ...', file=sys.stderr)

    sox[src_file, '-r', '44100', '-R', tgt_file, 'remix', '-', 'trim', '0', '10']()

    new_row = pd.Series({
        'path': tgt_file,
        'label': row['ebird_code'],
        'split': split
    })

    return new_row

df = df.apply(convert, axis=1)
df[df.split == 'train'].to_csv('data/cbi/annotations.train.csv')
df[df.split == 'valid'].to_csv('data/cbi/annotations.valid.csv')
df[df.split == 'test'].to_csv('data/cbi/annotations.test.csv')
# Out:
# Downloading birdsong-recognition.zip to data/cbi
# 100%|██████████| 22.1G/22.1G [12:57<00:00, 30.5MB/s]
# Archive:  data/cbi/birdsong-recognition.zip
#   inflating: data/cbi/example_test_audio/BLKFR-10-CPL_20190611_093000.pt540.mp3
#   inflating: data/cbi/example_test_audio/ORANGE-7-CAP_20190606_093000.pt623.mp3
#   inflating: data/cbi/example_test_audio_metadata.csv
#   inflating: data/cbi/example_test_audio_summary.csv
#   inflating: data/cbi/sample_submission.csv
#   inflating: data/cbi/test.csv
#   inflating: data/cbi/train.csv
#   inflating: data/cbi/train_audio/aldfly/XC134874.mp3
#   inflating: data/cbi/train_audio/aldfly/XC135454.mp3
#   inflating: data/cbi/train_audio/aldfly/XC135455.mp3
#   inflating: data/cbi/train_audio/aldfly/XC135456.mp3
#   inflating: data/cbi/train_audio/aldfly/XC135457.mp3
#   inflating: data/cbi/train_audio/aldfly/XC135459.mp3
#   inflating: data/cbi/train_audio/aldfly/XC135460.mp3
#   inflating: data/cbi/train_audio/aldfly/XC135883.mp3
#   inflating: data/cbi/train_audio/aldfly/XC137570.mp3
#   inflating: data/cbi/train_audio/aldfly/XC138639.mp3
#   inflating: data/cbi/train_audio/aldfly/XC139577.mp3
#   inflating: data/cbi/train_audio/aldfly/XC140298.mp3
#   inflating: data/cbi/train_audio/aldfly/XC142065.mp3
#   inflating: data/cbi/train_audio/aldfly/XC142066.mp3
mp3 ...
# Converting data/cbi/train_audio/yerwar/XC137662.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC138277.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC138282.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC138293.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC138298.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC138635.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC139869.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC142770.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC155359.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC164304.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC165035.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC165360.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC165361.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC169268.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC17028.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC173998.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC174698.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC176261.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC177064.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC177338.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC182570.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC183337.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC186314.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC187565.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC188141.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC188353.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC188619.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC189415.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC190065.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC190066.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC190067.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC190069.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC190070.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC193661.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC193662.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC203759.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC212491.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC213435.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC233727.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC239782.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC239790.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC244402.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC246986.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC247846.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC247849.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC252875.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC267988.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC269066.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC269067.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC269068.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC291112.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC291927.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC293119.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC296193.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC296194.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC296409.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC302645.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC304777.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC310941.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC319369.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC320341.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC324477.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC325118.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC325119.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC364122.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC364595.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC378354.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC378355.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC381698.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC389496.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC391179.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC391180.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC393846.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC408362.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC415419.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC415913.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC433107.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC448183.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC448725.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC467698.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC469517.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC469599.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC475039.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC475102.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC475291.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC499252.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC503063.mp3 ...
# Converting data/cbi/train_audio/yerwar/XC504133.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC120867.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC125806.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC126542.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC126544.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC130041.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC130042.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC134182.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC134183.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC134184.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC136303.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC136305.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC138160.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC138582.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC141565.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC147013.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC147074.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC154485.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC166321.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC17174.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC174699.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC174700.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC174712.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC174714.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC174715.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC177383.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC179085.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC179311.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC179321.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC182007.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC182329.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC182610.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC184090.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC194427.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC234650.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC247094.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC254792.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC254793.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC264265.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC292664.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC309313.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC309897.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC31129.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC31130.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC31131.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC315693.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC317172.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC317173.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC317495.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC321626.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC324469.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC324470.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC324976.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC325518.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC325519.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC325789.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC327903.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC329017.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC334205.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC344165.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC353822.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC357422.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC362476.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC362942.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC364309.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC365940.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC368489.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC371697.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC371698.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC371699.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC372011.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC375106.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC375955.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC376747.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC383356.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC384645.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC385850.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC389085.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC411461.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC417449.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC417452.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC417474.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC417989.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC417990.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC417991.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC418068.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC418325.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC420858.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC421946.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC425392.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC460595.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC467630.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC471316.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC477410.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC477608.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC500348.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC501230.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC54828.mp3 ...
# Converting data/cbi/train_audio/yetvir/XC55761.mp3 ...

# %% [markdown]
# #### 2. Convert to HF format

# %%
from datasets import Dataset, Audio
import pandas as pd

def load_dataset(split_name):
    df = pd.read_csv(f'data/cbi/annotations.{split_name}.csv')
    dataset = Dataset.from_pandas(df)
    dataset = dataset.cast_column('path', Audio())
    return dataset

splits = ['train', 'valid', 'test']
datasets = {split: load_dataset(split) for split in splits}
for split, dataset in datasets.items():
    print(dataset[0])
# Out:
# {'Unnamed: 0': 1, 'path': {'path': 'data/cbi/wav/XC135454.wav', 'array': array([ 0.        ,  0.        ,  0.        , ..., -0.00674438,
#        -0.00839233, -0.00601196]), 'sampling_rate': 44100}, 'label': 'aldfly', 'split': 'train'}
# {'Unnamed: 0': 0, 'path': {'path': 'data/cbi/wav/XC134874.wav', 'array': array([ 0.        ,  0.        ,  0.        , ..., -0.04196167,
#        -0.02774048,  0.01846313]), 'sampling_rate': 44100}, 'label': 'aldfly', 'split': 'valid'}
# {'Unnamed: 0': 8, 'path': {'path': 'data/cbi/wav/XC137570.wav', 'array': array([0.        , 0.        , 0.        , ..., 0.0015564 , 0.00189209,
#        0.00119019]), 'sampling_rate': 44100}, 'label': 'aldfly', 'split': 'test'}

# %% [markdown]
# #### 3. Upload the datasets to HF

# %%
for split, dataset in datasets.items():
    dataset.push_to_hub('DBD-research-group/beans_cbi', split=split)
# Out:
# Uploading the dataset shards:   0%|          | 0/24 [00:00<?, ?it/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/591 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/6 [00:00<?, ?it/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/592 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/591 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/591 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/591 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/591 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/402 [00:00<?, ?B/s]
# Uploading the dataset shards:   0%|          | 0/7 [00:00<?, ?it/s]
# Map:   0%|          | 0/518 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/517 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/517 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/517 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/517 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/517 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# Map:   0%|          | 0/517 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/510 [00:00<?, ?B/s]

# %% [markdown]
# ---
# # Download the dataset from HF

# %% [markdown]
# Download all splits from the hub. Even when specifying a specific split it still downloads everything! Use `streaming=True` and `cache_dir='...'` for shorter loading times.

# %%
from datasets import load_dataset, DatasetDict

#dataset = load_dataset(path='DBD-research-group/beans_cbi', split='train_low')
dataset: DatasetDict = load_dataset(name='default', path='DBD-research-group/beans_cbi')
# Out:
# Downloading readme:   0%|          | 0.00/615 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 from datasets import load_dataset, DatasetDict
#       3 #dataset = load_dataset(path='DBD-research-group/beans_cbi', split='train_low')
# ----> 4 dataset: DatasetDict = load_dataset(name='default', path='DBD-research-group/beans_cbi')
#
# File /workspace/.venv/lib/python3.10/site-packages/datasets/load.py:2556, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2551 verification_mode = VerificationMode(
#    2552     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2553 )
#    2555 # Create a dataset builder
# -> 2556 builder_instance = load_dataset_builder(
#    2557     path=path,
#    2558     name=name,
#    2559     data_dir=data_dir,
#    2560     data_files=data_files,
#    2561     cache_dir=cache_dir,
#    2562     features=features,
#    2563     download_config=download_config,
#    2564     download_mode=download_mode,
#    2565     revision=revision,
#    2566     token=token,
#    2567     storage_options=storage_options,
#    2568     trust_remote_code=trust_remote_code,
#    2569     _require_default_config_name=name is None,
#    2570     **config_kwargs,
#    2571 )
#    2573 # Return iterable dataset in case of streaming
#    2574 if streaming:
#
# File /workspace/.venv/lib/python3.10/site-packages/datasets/load.py:2228, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, use_auth_token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    2226     download_config = download_config.copy() if download_config else DownloadConfig()
#    2227     download_config.storage_options.update(storage_options)
# -> 2228 dataset_module = dataset_module_factory(
#    2229     path,
#    2230     revision=revision,
#    2231     download_config=download_config,
#    2232     download_mode=download_mode,
#    2233     data_dir=data_dir,
#    2234     data_files=data_files,
#    2235     cache_dir=cache_dir,
#    2236     trust_remote_code=trust_remote_code,
#    2237     _require_default_config_name=_require_default_config_name,
#    2238     _require_custom_configs=bool(config_kwargs),
#    2239 )
#    2240 # Get dataset builder class from the processing script
#    2241 builder_kwargs = dataset_module.builder_kwargs
#
# File /workspace/.venv/lib/python3.10/site-packages/datasets/load.py:1861, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1845         return HubDatasetModuleFactoryWithScript(
#    1846             path,
#    1847             revision=revision,
#    (...)
#    1851             trust_remote_code=trust_remote_code,
#    1852         ).get_module()
#    1853     else:
#    1854         return HubDatasetModuleFactoryWithoutScript(
#    1855             path,
#    1856             revision=revision,
#    1857             data_dir=data_dir,
#    1858             data_files=data_files,
#    1859             download_config=download_config,
#    1860             download_mode=download_mode,
# -> 1861         ).get_module()
#    1862 except Exception as e1:
#    1863     # All the attempts failed, before raising the error we should check if the module is already cached
#    1864     try:
#
# File /workspace/.venv/lib/python3.10/site-packages/datasets/load.py:1239, in HubDatasetModuleFactoryWithoutScript.get_module(self)
#    1237 else:
#    1238     patterns = get_data_patterns(base_path, download_config=self.download_config)
# -> 1239 data_files = DataFilesDict.from_patterns(
#    1240     patterns,
#    1241     base_path=base_path,
#    1242     allowed_extensions=ALL_ALLOWED_EXTENSIONS,
#    1243     download_config=self.download_config,
#    1244 )
#    1245 module_name, default_builder_kwargs = infer_module_for_data_files(
#    1246     data_files=data_files,
#    1247     path=self.name,
#    1248     download_config=self.download_config,
#    1249 )
#    1250 data_files = data_files.filter_extensions(_MODULE_TO_EXTENSIONS[module_name])
#
# File /workspace/.venv/lib/python3.10/site-packages/datasets/data_files.py:700, in DataFilesDict.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     697 out = cls()
#     698 for key, patterns_for_key in patterns.items():
#     699     out[key] = (
# --> 700         DataFilesList.from_patterns(
#     701             patterns_for_key,
#     702             base_path=base_path,
#     703             allowed_extensions=allowed_extensions,
#     704             download_config=download_config,
#     705         )
#     706         if not isinstance(patterns_for_key, DataFilesList)
#     707         else patterns_for_key
#     708     )
#     709 return out
#
# File /workspace/.venv/lib/python3.10/site-packages/datasets/data_files.py:605, in DataFilesList.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     602 for pattern in patterns:
#     603     try:
#     604         data_files.extend(
# --> 605             resolve_pattern(
#     606                 pattern,
#     607                 base_path=base_path,
#     608                 allowed_extensions=allowed_extensions,
#     609                 download_config=download_config,
#     610             )
#     611         )
#     612     except FileNotFoundError:
#     613         if not has_magic(pattern):
#
# File /workspace/.venv/lib/python3.10/site-packages/datasets/data_files.py:366, in resolve_pattern(pattern, base_path, allowed_extensions, download_config)
#     361 if protocol == "hf" and config.HF_HUB_VERSION >= version.parse("0.20.0"):
#     362     # 10 times faster glob with detail=True (ignores costly info like lastCommit)
#     363     glob_kwargs["expand_info"] = False
#     364 matched_paths = [
#     365     filepath if filepath.startswith(protocol_prefix) else protocol_prefix + filepath
# --> 366     for filepath, info in fs.glob(pattern, detail=True, **glob_kwargs).items()
#     367     if info["type"] == "file"
#     368     and (xbasename(filepath) not in files_to_ignore)
#     369     and not _is_inside_unrequested_special_dir(
#     370         os.path.relpath(filepath, fs_base_path), os.path.relpath(fs_pattern, fs_base_path)
#     371     )
#     372     and not _is_unrequested_hidden_file_or_is_inside_unrequested_hidden_dir(
#     373         os.path.relpath(filepath, fs_base_path), os.path.relpath(fs_pattern, fs_base_path)
#     374     )
#     375 ]  # ignore .ipynb and __pycache__, but keep /../
#     376 if allowed_extensions is not None:
#     377     out = [
#     378         filepath
#     379         for filepath in matched_paths
#     380         if any("." + suffix in allowed_extensions for suffix in xbasename(filepath).split(".")[1:])
#     381     ]
#
# File /workspace/.venv/lib/python3.10/site-packages/huggingface_hub/hf_file_system.py:397, in HfFileSystem.glob(self, path, **kwargs)
#     395 kwargs = {"expand_info": kwargs.get("detail", False), **kwargs}
#     396 path = self.resolve_path(path, revision=kwargs.get("revision")).unresolve()
# --> 397 return super().glob(path, **kwargs)
#
# File /workspace/.venv/lib/python3.10/site-packages/fsspec/spec.py:604, in AbstractFileSystem.glob(self, path, maxdepth, **kwargs)
#     601     else:
#     602         depth = None
# --> 604 allpaths = self.find(root, maxdepth=depth, withdirs=True, detail=True, **kwargs)
#     606 pattern = glob_translate(path + ("/" if ends_with_sep else ""))
#     607 pattern = re.compile(pattern)
#
# File /workspace/.venv/lib/python3.10/site-packages/huggingface_hub/hf_file_system.py:410, in HfFileSystem.find(self, path, maxdepth, withdirs, detail, refresh, revision, **kwargs)
#     399 def find(
#     400     self,
#     401     path: str,
#    (...)
#     407     **kwargs,
#     408 ) -> Union[List[str], Dict[str, Dict[str, Any]]]:
#     409     if maxdepth:
# --> 410         return super().find(
#     411             path, maxdepth=maxdepth, withdirs=withdirs, detail=detail, refresh=refresh, revision=revision, **kwargs
#     412         )
#     413     resolved_path = self.resolve_path(path, revision=revision)
#     414     path = resolved_path.unresolve()
#
# File /workspace/.venv/lib/python3.10/site-packages/fsspec/spec.py:494, in AbstractFileSystem.find(self, path, maxdepth, withdirs, detail, **kwargs)
#     490 out = {}
#     492 # Add the root directory if withdirs is requested
#     493 # This is needed for posix glob compliance
# --> 494 if withdirs and path != "" and self.isdir(path):
#     495     out[path] = self.info(path)
#     497 for _, dirs, files in self.walk(path, maxdepth, detail=True, **kwargs):
#
# File /workspace/.venv/lib/python3.10/site-packages/huggingface_hub/hf_file_system.py:569, in HfFileSystem.isdir(self, path)
#     567 """Is this entry directory-like?"""
#     568 try:
# --> 569     return self.info(path, expand_info=False)["type"] == "directory"
#     570 except OSError:
#     571     return False
#
# File /workspace/.venv/lib/python3.10/site-packages/huggingface_hub/hf_file_system.py:517, in HfFileSystem.info(self, path, refresh, revision, **kwargs)
#     515     out = out1[0]
#     516 if refresh or out is None or (expand_info and out and out["last_commit"] is None):
# --> 517     paths_info = self._api.get_paths_info(
#     518         resolved_path.repo_id,
#     519         resolved_path.path_in_repo,
#     520         expand=expand_info,
#     521         revision=resolved_path.revision,
#     522         repo_type=resolved_path.repo_type,
#     523     )
#     524     if not paths_info:
#     525         _raise_file_not_found(path, None)
#
# File /workspace/.venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     115 if check_use_auth_token:
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File /workspace/.venv/lib/python3.10/site-packages/huggingface_hub/hf_api.py:3137, in HfApi.get_paths_info(self, repo_id, paths, expand, revision, repo_type, token)
#    3134 revision = quote(revision, safe="") if revision is not None else DEFAULT_REVISION
#    3135 headers = self._build_hf_headers(token=token)
# -> 3137 response = get_session().post(
#    3138     f"{self.endpoint}/api/{repo_type}s/{repo_id}/paths-info/{revision}",
#    3139     data={
#    3140         "paths": paths if isinstance(paths, list) else [paths],
#    3141         "expand": expand,
#    3142     },
#    3143     headers=headers,
#    3144 )
#    3145 hf_raise_for_status(response)
#    3146 paths_info = response.json()
#
# File /workspace/.venv/lib/python3.10/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File /workspace/.venv/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /workspace/.venv/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /workspace/.venv/lib/python3.10/site-packages/huggingface_hub/utils/_http.py:67, in UniqueRequestIdAdapter.send(self, request, *args, **kwargs)
#      65 """Catch any RequestException to append request id to the error message for debugging."""
#      66 try:
# ---> 67     return super().send(request, *args, **kwargs)
#      68 except requests.RequestException as e:
#      69     request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# File /workspace/.venv/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /workspace/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File /workspace/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /workspace/.venv/lib/python3.10/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.10/ssl.py:1303, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1299     if flags != 0:
#    1300         raise ValueError(
#    1301           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302           self.__class__)
# -> 1303     return self.read(nbytes, buffer)
#    1304 else:
#    1305     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.10/ssl.py:1159, in SSLSocket.read(self, len, buffer)
#    1157 try:
#    1158     if buffer is not None:
# -> 1159         return self._sslobj.read(len, buffer)
#    1160     else:
#    1161         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# print number of samples and number of distinct classes
print(f"Number of samples: {len(dataset['train'])}")
print(f"Number of distinct classes: {len(dataset['train'].unique('label'))}")
dataset
# Out:
# Number of samples: 1200
# Number of distinct classes: 10
