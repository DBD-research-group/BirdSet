# %% [markdown]
# # Upload the BEANS egyptian fruit bats recordings to HF

# %% [markdown]
# #### 1. Download the recordings the way BEANS do it on their [GitHub](https://github.com/earthspecies/beans)

# %% [markdown]
# First we will navigate into the mounted data_birdset folder to download the temporary files from the Repo their

# %%
# %cd '../../../data_birdset/beans'
# !pwd
# Out:
# /workspace/data_birdset/beans
# /workspace/data_birdset/beans
# /home/vscode/.cache/pypoetry/virtualenvs/birdset-xS3fZVNL-py3.10/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# Then we will run their script to download the metadata and recordings. Note that you need to have wget installed.

# %%
# Their script:
import pandas as pd
from sklearn.model_selection import train_test_split
from plumbum import local, FG

#local['mkdir']['-p', 'data/egyptian_fruit_bats']()
#local['wget']['https://archive.org/download/egyptian_fruit_bats_10k/egyptian_fruit_bats.zip', '-P', 'data/egyptian_fruit_bats'] & FG
local['unzip']['data/egyptian_fruit_bats/egyptian_fruit_bats.zip', '-d', 'data/egyptian_fruit_bats/'] & FG

df = pd.read_csv('data/egyptian_fruit_bats/annotations.csv')
df = df.apply(lambda r: pd.Series({'path': f"data/egyptian_fruit_bats/audio/{r['File Name']}", 'label': r['Emitter']}), axis=1)

# split to train:valid:test = 6:2:2
df_train, df_valid_test = train_test_split(df, test_size=0.4, random_state=42, shuffle=True, stratify=df['label'])
df_valid, df_test = train_test_split(df_valid_test, test_size=0.5, random_state=42, shuffle=True, stratify=df_valid_test['label'])
df_train_low, _ = train_test_split(df_train, test_size=0.8, random_state=42, shuffle=True, stratify=df_train['label'])

df_train = df_train.sort_index()
df_train_low = df_train_low.sort_index()
df_valid = df_valid.sort_index()
df_test = df_test.sort_index()

df_train.to_csv('data/egyptian_fruit_bats/annotations.train.csv')
df_train_low.to_csv('data/egyptian_fruit_bats/annotations.train-low.csv')
df_valid.to_csv('data/egyptian_fruit_bats/annotations.valid.csv')
df_test.to_csv('data/egyptian_fruit_bats/annotations.test.csv')
# Out:
# Archive:  data/egyptian_fruit_bats/egyptian_fruit_bats.zip
#   inflating: data/egyptian_fruit_bats/annotations.csv
#    creating: data/egyptian_fruit_bats/audio/
#   inflating: data/egyptian_fruit_bats/audio/84828.wav
#   inflating: data/egyptian_fruit_bats/audio/73671.wav
#   inflating: data/egyptian_fruit_bats/audio/77193.wav
#   inflating: data/egyptian_fruit_bats/audio/57444.wav
#   inflating: data/egyptian_fruit_bats/audio/76992.wav
#   inflating: data/egyptian_fruit_bats/audio/78189.wav
#   inflating: data/egyptian_fruit_bats/audio/46143.wav
#   inflating: data/egyptian_fruit_bats/audio/19722.wav
#   inflating: data/egyptian_fruit_bats/audio/66150.wav
#   inflating: data/egyptian_fruit_bats/audio/13063.wav
#   inflating: data/egyptian_fruit_bats/audio/26843.wav
#   inflating: data/egyptian_fruit_bats/audio/71329.wav
#   inflating: data/egyptian_fruit_bats/audio/41206.wav
#   inflating: data/egyptian_fruit_bats/audio/34986.wav
# ...
