# %%
import pandas as pd 
from datasets import Dataset, Audio, Features

# %%
metadata = pd.read_csv('data/metadata/metadata_na_1k.csv', index_col='id')

# %%
metadata["file_name"].iloc[0]
# Out:
# 'data/xeno-canto/north_america/campylorhynchus_brunneicapillus/XC241017.ogg'

# %%
metadata
# Out:
#             lat       lng  type        sex                          primary
# id
# 241017  31.4312 -110.2366  song        NaN  campylorhynchus brunneicapillus  \
# 741556  17.8693  -97.0266  song        NaN               vireo hypochryseus
# 796595  43.0706  -76.0712  call  uncertain            corvus brachyrhynchos
# 796809  17.1543  -88.8522  song        NaN             cyanoloxia cyanoides
# 236014  29.7599  -95.4468  song        NaN         thryothorus ludovicianus
# ...         ...       ...   ...        ...                              ...
# 483029  44.7233  -69.8220  song        NaN                  toxostoma rufum
# 52444   44.3670  -71.5270  song        NaN          geothlypis philadelphia
# 614146  15.6690  -96.5732  call       male          cassiculus melanicterus
# 179227  41.8087  -72.0647  song        NaN                setophaga citrina
# 661352  29.6683 -114.9188  song       male                melospiza melodia
#
#             continent                                          secondary
# id
# 241017  North America  ['Zenaida asiatica', 'Haemorhous mexicanus', '...  \
# 741556  North America                                                 []
# 796595  North America                                                 []
# 796809  North America                                                 []
# 236014  North America                                                 []
# ...               ...                                                ...
# 483029  North America                                                 []
# 52444   North America  ['Vireo solitarius', 'Geothlypis trichas', 'Le...
# 614146  North America                                                 []
# 179227  North America                           ['Hylocichla mustelina']
# 661352  North America  ['Sayornis nigricans', 'Zenaida asiatica', 'Ic...
#
#                                                 file_name ebird_code
# id
# 241017  data/xeno-canto/north_america/campylorhynchus_...     cacwre
# 741556  data/xeno-canto/north_america/vireo_hypochryse...    golvir1
# 796595  data/xeno-canto/north_america/corvus_brachyrhy...     amecro
# 796809  data/xeno-canto/north_america/cyanoloxia_cyano...    bubgro1
# 236014  data/xeno-canto/north_america/thryothorus_ludo...     carwre
# ...                                                   ...        ...
# 483029  data/xeno-canto/north_america/toxostoma_rufum/...     brnthr
# 52444   data/xeno-canto/north_america/geothlypis_phila...     mouwar
# 614146  data/xeno-canto/north_america/cassiculus_melan...    yewcac1
# 179227  data/xeno-canto/north_america/setophaga_citrin...     hoowar
# 661352  data/xeno-canto/north_america/melospiza_melodi...     sonspa
#
# [1000 rows x 9 columns]

# %%
na1k = Dataset.from_pandas(metadata)

# %%
file_column = na1k["file_name"]

# %%
na1k = na1k.add_column("file", na1k["file_name"])

# %%
na1k
# Out:
# Dataset({
#     features: ['lat', 'lng', 'type', 'sex', 'primary', 'continent', 'secondary', 'file_name', 'ebird_code', 'id', 'file'],
#     num_rows: 1000
# })

# %%
na1k = na1k.rename_column("file_name", "audio")

# %%
# decode can be set True or False 
na1k = na1k.cast_column(
    column="audio", 
    feature= Audio(
            sampling_rate=16_000,
            mono=True,
            decode=True
    )
)

# %%
na1k[0]
# Out:
# {'lat': 31.4312,
#  'lng': -110.2366,
#  'type': 'song',
#  'sex': None,
#  'primary': 'campylorhynchus brunneicapillus',
#  'continent': 'North America',
#  'secondary': "['Zenaida asiatica', 'Haemorhous mexicanus', 'Streptopelia decaocto', 'Callipepla gambelii']",
#  'audio': {'path': 'data/xeno-canto/NA_subset1k/XC241017.mp3',
#   'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          -2.55924442e-06, -2.74799049e-06,  0.00000000e+00]),
#   'sampling_rate': 16000},
#  'ebird_code': 'cacwre',
#  'id': 241017}

# %%
from collections import Counter

print(f"Number of samples: {len(na1k['id'])}")
birds = Counter(na1k['ebird_code'])
print(f"Number of classes: {len(birds)}")
print(birds)
# Out:
# Number of samples: 1000
# Number of classes: 514
# Counter({None: 24, 'houwre': 10, 'sonspa': 9, 'rewbla': 9, 'marwre': 8, 'brncre': 8, 'comyel': 8, 'swathr': 8, 'amerob': 8, 'carwre': 7, 'purmar': 7, 'whtspa': 7, 'tuftit': 7, 'gnttow': 7, 'comrav': 7, 'wesmea': 7, 'nswowl': 7, 'savspa': 6, 'bewwre': 6, 'eastow': 6, 'spotow': 6, 'blujay': 6, 'gockin': 6, 'hoowar': 6, 'foxspa': 6, 'amecro': 5, 'grcfly': 5, 'bknsti': 5, 'wlswar': 5, 'brdowl': 5, 'rubcha1': 5, 'stejay': 5, 'brthum': 5, 'norcar': 5, 'norpar': 5, 'whcspa': 5, 'mouwar': 5, 'bubgro1': 4, 'macwar': 4, 'norwat': 4, 'chispa': 4, 'redcro': 4, 'belvir': 4, 'sumtan': 4, 'chswar': 4, 'cubthr': 4, 'balori': 4, 'bktspa': 4, 'virrai': 4, 'btywar': 4, 'annhum': 4, 'ridrai1': 4, 'daejun': 4, 'lazbun': 4, 'veery': 4, 'acafly': 4, 'yebcuc': 4, 'bkcchi': 4, 'woothr': 3, 'grhowl': 3, 'spwqua1': 3, 'winwre3': 3, 'whbeme1': 3, 'rebwoo': 3, 'orcwar': 3, 'mewgul2': 3, 'ovenbi1': 3, 'ruckin': 3, 'sora': 3, 'magwar': 3, 'nrwswa': 3, 'eletro': 3, 'acowoo': 3, 'grycat': 3, 'bkhgro': 3, 'amtspa': 3, 'rebpig1': 3, 'amewoo': 3, 'scoori': 3, 'sinwre1': 3, 'laplon': 3, 'amegfi': 3, 'coffal1': 3, 'souwpw1': 3, 'calqua': 3, 'yerwar': 3, 'yehbla': 3, 'phivir': 3, 'verdin': 3, 'buwwar': 3, 'bkcgna': 3, 'cantow': 3, 'amgplo': 3, 'paired': 3, 'norjac': 3, 'brratt1': 3, 'caskin': 3, 'naswar': 3, 'whttow1': 3, 'houfin': 3, 'scatan': 3, 'dickci': 3, 'corfly': 3, 'cacwre': 2, 'golvir1': 2, 'clcspa': 2, 'louwat': 2, 'brbsol1': 2, 'bkchum': 2, 'labwoo': 2, 'whcsee2': 2, 'lawgol': 2, 'banwre1': 2, 'amekes': 2, 'easblu': 2, 'batpig1': 2, 'pygnut': 2, 'cangoo': 2, 'cogdov': 2, 'pasfly': 2, 'carchi': 2, 'cinhum1': 2, 'laufal1': 2, 'horlar': 2, 'rotbec': 2, 'amedip': 2, 'maghum1': 2, 'dusant1': 2, 'mouchi': 2, 'easkin': 2, 'comnig': 2, 'gamqua': 2, 'compau': 2, 'fepowl': 2, 'rucspa': 2, 'rocwre': 2, 'baispa': 2, 'sonwre1': 2, 'burowl': 2, 'rebnut': 2, 'rubpep1': 2, 'bacspa': 2, 'belkin1': 2, 'willet1': 2, 'astfly': 2, 'flafly1': 2, 'grcdov1': 2, 'nopowl': 2, 'lesgol': 2, 'screup1': 2, 'abetow': 2, 'shtgro': 2, 'buhvir': 2, 'lucwar': 2, 'redpha1': 2, 'clcrob': 2, 'warvir': 2, 'btnwar': 2, 'grbcra1': 2, 'casfin': 2, 'wewpew': 2, 'blhant2': 2, 'dunlin': 2, 'blctit4': 2, 'ivbwoo1': 2, 'canwar': 2, 'pinsis': 2, 'linwoo1': 2, 'rufpih1': 2, 'pacwre1': 2, 'yebcha': 2, 'plsvir': 2, 'greyel': 2, 'whehum': 2, 'gocwoo1': 2, 'bucnig': 2, 'grekis': 2, 'whtcra1': 2, 'yetwar': 2, 'bkpwar': 2, 'calgul': 2, 'brocow': 2, 'bltgro1': 2, 'olsfly': 2, 'leater1': 2, 'wbwwre1': 2, 'yewcac1': 2, 'whsowl1': 2, 'pabwoo1': 2, 'houspa': 2, 'calthr': 2, 'rtlhum': 2, 'squcuc1': 2, 'nutfly': 2, 'y00475': 2, 'fatwar': 2, 'towwar': 2, 'borchi2': 2, 'y00599': 2, 'grtgra': 2, 'mallar3': 2, 'wesowl1': 2, 'amered': 2, 'gryjay': 2, 'buggna': 2, 'brespa': 2, 'borowl': 2, 'comgal1': 2, 'sagthr': 2, 'roahaw': 2, 'bkbmag1': 2, 'merlin': 2, 'greroa': 2, 'bkbcuc': 2, 'rawwre1': 2, 'yebfly': 2, 'sthspa1': 2, 'yetvir': 1, 'snogoo': 1, 'olitan1': 1, 'coohaw': 1, 'redcro9': 1, 'lecspa': 1, 'bobfly1': 1, 'brhpar1': 1, 'baywre1': 1, 'bbnthr1': 1, 'swaspa': 1, 'brispa1': 1, 'westan': 1, 'olcwar1': 1, 'aldfly': 1, 'lobgna5': 1, 'norbob': 1, 'wesspi': 1, 'robgro': 1, 'monoro1': 1, 'ruwspa': 1, 'amebit': 1, 'bkbwar': 1, 'grepew': 1, 'bkbwoo': 1, 'rudcra1': 1, 'hoared': 1, 'pabspi1': 1, 'kirwar': 1, 'unijay1': 1, 'prawar': 1, 'fiscro': 1, 'neocor': 1, 'lesgre1': 1, 'reevir1': 1, 'sursco': 1, 'blkrai': 1, 'hawcre': 1, 'tromoc': 1, 'canwre': 1, 'iiwi': 1, 'yercac1': 1, 'bcwpar1': 1, 'botspa': 1, 'strcuc1': 1, 'bkwvir': 1, 'snoegr': 1, 'elequa': 1, 'apapan': 1, 'sancra': 1, 'babwre1': 1, 'copowl1': 1, 'manvir1': 1, 'grasal2': 1, 'incdov': 1, 'btbwar': 1, 'belspa2': 1, 'colred1': 1, 'pilwoo': 1, 'purfin': 1, 'spbwre1': 1, 'gocman1': 1, 'kinrai4': 1, 'luchum': 1, 'purgal2': 1, 'solsan': 1, 'grykin': 1, 'ribgul': 1, 'juntit1': 1, 'greegr': 1, 'yelwar': 1, 'robbun1': 1, 'crcwar': 1, 'blubun': 1, 'monpar': 1, 'cubpar1': 1, 'banana': 1, 'nstspa': 1, 'easpho': 1, 'woosto': 1, 'rucmot1': 1, 'cobtan1': 1, 'grnpar': 1, 'rtatan1':  ...

# %%
from huggingface_hub import login

login()
# Out:
# VBox(children=(HTML(value='<center> <img\nbirdset=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
na1k.push_to_hub(
    repo_id="DBD-research-group/xeno-canto_na_1k_nodecode",
    private=True,
    embed_external_files=True
)

# took ~45 minutes
# Out:
# Exception ignored in: <function Dataset.__del__ at 0x7f1cf8404d30>
# Traceback (most recent call last):
#   File "/home/lukas/miniconda3/envs/dal-toolbox/lib/python3.9/site-packages/datasets/arrow_dataset.py", line 1339, in __del__
#     def __del__(self):
# KeyboardInterrupt:
# Map:   0%|          | 0/250 [00:00<?, ? examples/s]

# %%
import matplotlib.pyplot as plt 
value_counts = metadata['ebird_code'].value_counts()
value_counts.plot(kind='bar')
plt.show()

# %%
import matplotlib.pyplot as plt 
value_counts = metadata['primary'].value_counts()
value_counts.plot(kind='bar')
plt.show()

# %%
test = na1k.class_encode_column('primary')
# Out:
# Casting to class labels:   0%|          | 0/5396 [00:00<?, ? examples/s]

# %%
birds = Counter(test['primary'])
print(f"Number of classes: {len(birds)}")
print(birds)
# Out:
# Number of classes: 40
# Counter({37: 675, 15: 325, 12: 315, 11: 308, 19: 237, 6: 213, 28: 206, 8: 178, 21: 176, 17: 176, 3: 170, 5: 167, 35: 160, 22: 147, 16: 124, 29: 118, 32: 113, 4: 107, 31: 107, 39: 106, 30: 105, 1: 103, 36: 99, 2: 89, 18: 83, 33: 74, 26: 69, 27: 67, 24: 66, 13: 60, 25: 59, 7: 57, 20: 55, 38: 54, 34: 52, 0: 45, 10: 43, 9: 42, 14: 24, 23: 22})

# %%
na5k_split = na1k.class_encode_column('primary').train_test_split(test_size=0.2, stratify_by_column='primary')
# Out:
# Casting to class labels:   0%|          | 0/5396 [00:00<?, ? examples/s]

# %%
na5k_split["train"].features
# Out:
# {'lat': Value(dtype='float64', id=None),
#  'lng': Value(dtype='float64', id=None),
#  'type': Value(dtype='string', id=None),
#  'sex': Value(dtype='string', id=None),
#  'primary': ClassLabel(names=['agelaius tricolor', 'antrostomus carolinensis', 'archilochus alexandri', 'auriparus flaviceps', 'bombycilla cedrorum', 'branta canadensis', 'calypte anna', 'campylorhynchus capistratus', 'charadrius vociferus', 'charadrius wilsonia', 'chroicocephalus philadelphia', 'corvus brachyrhynchos', 'dumetella carolinensis', 'gavia immer', 'geococcyx velox', 'haemorhous mexicanus', 'junco phaeonotus', 'lanius ludovicianus', 'leucolia violiceps', 'melanotis caerulescens', 'momotus mexicanus', 'myiarchus crinitus', 'peucaea carpalis', 'phasianus colchicus', 'pheucticus chrysopeplus', 'pica hudsonia', 'picoides dorsalis', 'procnias tricarunculatus', 'regulus satrapa', 'setophaga caerulescens', 'setophaga discolor', 'setophaga fusca', 'setophaga townsendi', 'sterna forsteri', 'tiaris olivaceus', 'toxostoma rufum', 'tringa melanoleuca', 'troglodytes aedon', 'trogon mexicanus', 'tyrannus verticalis'], id=None),
#  'continent': Value(dtype='string', id=None),
#  'secondary': Value(dtype='string', id=None),
#  'audio': Audio(sampling_rate=16000, mono=True, decode=True, id=None),
#  'ebird_code': Value(dtype='string', id=None),
#  'id': Value(dtype='int64', id=None)}

# %%
na5k_split["train"].features["primary"].int2str(2)
# Out:
# 'archilochus alexandri'

# %% [markdown]
# Set Tranform vs Cast Column
