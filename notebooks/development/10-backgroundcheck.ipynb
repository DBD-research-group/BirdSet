# %%
import os
import numpy as np

# %%
os.chdir('/home/lrauch/projects/BirdSet/output/debug/runs/xenocanto_m_withoutnd/ast/2024-01-05_163005')

# %%
import IPython

# %%
IPython.display.Audio(filename="audio/audio_0.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source birdset="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
os.chdir('/home/lrauch/projects/BirdSet/datq_birdset/background_noise/dcase18_unpacked/debug/runs/xenocanto_m_withoutnd/ast/2024-01-05_163005')
